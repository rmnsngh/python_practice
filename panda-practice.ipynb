# %% [markdown]
# # pandas Practice
#
# Answer the questions below by writing some pandas code and using the dataframe saved to the `df` variable. The answer to the question should be in the cell's output!

# %%
import pandas as pd

# %%
df = pd.read_csv("data/gapminder_all.csv", index_col="country")

# %%
df
# Out:
#                continent  gdpPercap_1952  gdpPercap_1957  gdpPercap_1962  \
# country
# Algeria           Africa     2449.008185     3013.976023     2550.816880
# Angola            Africa     3520.610273     3827.940465     4269.276742
# Benin             Africa     1062.752200      959.601080      949.499064
# Botswana          Africa      851.241141      918.232535      983.653976
# Burkina Faso      Africa      543.255241      617.183465      722.512021
# ...                  ...             ...             ...             ...
# Switzerland       Europe    14734.232750    17909.489730    20431.092700
# Turkey            Europe     1969.100980     2218.754257     2322.869908
# United Kingdom    Europe     9979.508487    11283.177950    12477.177070
# Australia        Oceania    10039.595640    10949.649590    12217.226860
# New Zealand      Oceania    10556.575660    12247.395320    13175.678000
#
#                 gdpPercap_1967  gdpPercap_1972  gdpPercap_1977  \
# country
# ...

# %%
df.columns
# Out:
# Index(['continent', 'gdpPercap_1952', 'gdpPercap_1957', 'gdpPercap_1962',
#        'gdpPercap_1967', 'gdpPercap_1972', 'gdpPercap_1977', 'gdpPercap_1982',
#        'gdpPercap_1987', 'gdpPercap_1992', 'gdpPercap_1997', 'gdpPercap_2002',
#        'gdpPercap_2007', 'lifeExp_1952', 'lifeExp_1957', 'lifeExp_1962',
#        'lifeExp_1967', 'lifeExp_1972', 'lifeExp_1977', 'lifeExp_1982',
#        'lifeExp_1987', 'lifeExp_1992', 'lifeExp_1997', 'lifeExp_2002',
#        'lifeExp_2007', 'pop_1952', 'pop_1957', 'pop_1962', 'pop_1967',
#        'pop_1972', 'pop_1977', 'pop_1982', 'pop_1987', 'pop_1992', 'pop_1997',
#        'pop_2002', 'pop_2007'],
#       dtype='object')

# %% [markdown]
# Example: What was the GDP per cap of Turkey in 1972?

# %%
df.loc["Turkey", "gdpPercap_1972"]
# Out:
# 3450.69638

# %% [markdown]
# Question #1: What was the population of Egypt in 1987?

# %% [markdown]
# Question #2: What was the life expectancy in Singapore from 1952-2002?

# %% [markdown]
# Question #3: Use describe() to show some summary statistics about GDP per cap for countries in the Americas
#
# Bonus: display each year as a row and each summary statistic as a column

# %% [markdown]
# Question #4: How many countries are in each continent?

# %% [markdown]
# Question #5: First, find the minimum life expectancies for all countries with a higher than average GDP (for that year). Then, find the maximum life expectancies for all countries with a lower than average GDP (for that year)
#
# Hint:
# 1. Find the average GDP (per year)

# %% [markdown]
# df_gdp = df[[gdpPercap_1952	gdpPercap_1957	gdpPercap_1962	gdpPercap_1967	gdpPercap_1972	gdpPercap_1977	gdpPercap_1982	gdpPercap_1987	gdpPercap_1992]]

# %%
df_gdp = df[['gdpPercap_1952', 'gdpPercap_1957', 'gdpPercap_1962',
       'gdpPercap_1967', 'gdpPercap_1972', 'gdpPercap_1977', 'gdpPercap_1982',
       'gdpPercap_1987', 'gdpPercap_1992', 'gdpPercap_1997', 'gdpPercap_2002',
       'gdpPercap_2007']]
df_gdp.head()
# Out:
#               gdpPercap_1952  gdpPercap_1957  gdpPercap_1962  gdpPercap_1967  \
# country
# Algeria          2449.008185     3013.976023     2550.816880     3246.991771
# Angola           3520.610273     3827.940465     4269.276742     5522.776375
# Benin            1062.752200      959.601080      949.499064     1035.831411
# Botswana          851.241141      918.232535      983.653976     1214.709294
# Burkina Faso      543.255241      617.183465      722.512021      794.826560
#
#               gdpPercap_1972  gdpPercap_1977  gdpPercap_1982  gdpPercap_1987  \
# country
# Algeria          4182.663766     4910.416756     5745.160213     5681.358539
# Angola           5473.288005     3008.647355     2756.953672     2430.208311
# Benin            1085.796879     1029.161251     1277.897616     1225.856010
# Botswana         2263.611114     3214.857818     4551.142150     6205.883850
# Burkina Faso      854.735976      743.387037      807.198586      912.063142
#
# ...

# %%
df_gdp = df.loc[ : , 'gdpPercap_1952 : gdpPercap_2007']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File c:\Users\171693\Documents\GitHub\python_practice\.env\lib\site-packages\pandas\core\indexes\base.py:3652, in Index.get_loc(self, key)
#    3651 try:
# -> 3652     return self._engine.get_loc(casted_key)
#    3653 except KeyError as err:
#
# File c:\Users\171693\Documents\GitHub\python_practice\.env\lib\site-packages\pandas\_libs\index.pyx:147, in pandas._libs.index.IndexEngine.get_loc()
#
# File c:\Users\171693\Documents\GitHub\python_practice\.env\lib\site-packages\pandas\_libs\index.pyx:176, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\_libs\hashtable_class_helper.pxi:7080, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\_libs\hashtable_class_helper.pxi:7088, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'gdpPercap_1952 : gdpPercap_2007'
#
# ...
