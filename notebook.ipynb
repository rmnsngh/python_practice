# %% [markdown]
# ### Notebook for Python Practice Class

# %%
import pandas as pd

# %%
df_oceania = pd.read_csv("data/gapminder_gdp_oceania.csv", index_col = 'country')

# %%
df_oceania
# Out:
#              gdpPercap_1952  gdpPercap_1957  gdpPercap_1962  gdpPercap_1967  \
# country
# Australia       10039.59564     10949.64959     12217.22686     14526.12465
# New Zealand     10556.57566     12247.39532     13175.67800     14463.91893
#
#              gdpPercap_1972  gdpPercap_1977  gdpPercap_1982  gdpPercap_1987  \
# country
# Australia       16788.62948     18334.19751     19477.00928     21888.88903
# New Zealand     16046.03728     16233.71770     17632.41040     19007.19129
#
#              gdpPercap_1992  gdpPercap_1997  gdpPercap_2002  gdpPercap_2007
# country
# Australia       23424.76683     26997.93657     30687.75473     34435.36744
# New Zealand     18363.32494     21050.41377     23189.80135     25185.00911

# %%
df_oceania.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 2 entries, Australia to New Zealand
# Data columns (total 12 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   gdpPercap_1952  2 non-null      float64
#  1   gdpPercap_1957  2 non-null      float64
#  2   gdpPercap_1962  2 non-null      float64
#  3   gdpPercap_1967  2 non-null      float64
#  4   gdpPercap_1972  2 non-null      float64
#  5   gdpPercap_1977  2 non-null      float64
#  6   gdpPercap_1982  2 non-null      float64
#  7   gdpPercap_1987  2 non-null      float64
#  8   gdpPercap_1992  2 non-null      float64
#  9   gdpPercap_1997  2 non-null      float64
#  10  gdpPercap_2002  2 non-null      float64
#  11  gdpPercap_2007  2 non-null      float64
# dtypes: float64(12)
# memory usage: 208.0+ bytes

# %%
df_oceania.columns
# Out:
# Index(['gdpPercap_1952', 'gdpPercap_1957', 'gdpPercap_1962', 'gdpPercap_1967',
#        'gdpPercap_1972', 'gdpPercap_1977', 'gdpPercap_1982', 'gdpPercap_1987',
#        'gdpPercap_1992', 'gdpPercap_1997', 'gdpPercap_2002', 'gdpPercap_2007'],
#       dtype='object')

# %%
cols = list(df_oceania.columns)
cols
# Out:
# ['gdpPercap_1952',
#  'gdpPercap_1957',
#  'gdpPercap_1962',
#  'gdpPercap_1967',
#  'gdpPercap_1972',
#  'gdpPercap_1977',
#  'gdpPercap_1982',
#  'gdpPercap_1987',
#  'gdpPercap_1992',
#  'gdpPercap_1997',
#  'gdpPercap_2002',
#  'gdpPercap_2007']

# %%
df_oceania.T # transpose the df
# Out:
# country           Australia  New Zealand
# gdpPercap_1952  10039.59564  10556.57566
# gdpPercap_1957  10949.64959  12247.39532
# gdpPercap_1962  12217.22686  13175.67800
# gdpPercap_1967  14526.12465  14463.91893
# gdpPercap_1972  16788.62948  16046.03728
# gdpPercap_1977  18334.19751  16233.71770
# gdpPercap_1982  19477.00928  17632.41040
# gdpPercap_1987  21888.88903  19007.19129
# gdpPercap_1992  23424.76683  18363.32494
# gdpPercap_1997  26997.93657  21050.41377
# gdpPercap_2002  30687.75473  23189.80135
# gdpPercap_2007  34435.36744  25185.00911

# %%
df_oceania.describe()
# Out:
#        gdpPercap_1952  gdpPercap_1957  gdpPercap_1962  gdpPercap_1967  \
# count        2.000000        2.000000        2.000000        2.000000
# mean     10298.085650    11598.522455    12696.452430    14495.021790
# std        365.560078      917.644806      677.727301       43.986086
# min      10039.595640    10949.649590    12217.226860    14463.918930
# 25%      10168.840645    11274.086022    12456.839645    14479.470360
# 50%      10298.085650    11598.522455    12696.452430    14495.021790
# 75%      10427.330655    11922.958888    12936.065215    14510.573220
# max      10556.575660    12247.395320    13175.678000    14526.124650
#
#        gdpPercap_1972  gdpPercap_1977  gdpPercap_1982  gdpPercap_1987  \
# count         2.00000        2.000000        2.000000        2.000000
# mean      16417.33338    17283.957605    18554.709840    20448.040160
# std         525.09198     1485.263517     1304.328377     2037.668013
# ...

# %%
df_americas = pd.read_csv("data/gapminder_gdp_americas.csv", index_col = 'country')

# %%
df_americas
# Out:
#                     continent  gdpPercap_1952  gdpPercap_1957  gdpPercap_1962  \
# country
# Argentina            Americas     5911.315053     6856.856212     7133.166023
# Bolivia              Americas     2677.326347     2127.686326     2180.972546
# Brazil               Americas     2108.944355     2487.365989     3336.585802
# Canada               Americas    11367.161120    12489.950060    13462.485550
# Chile                Americas     3939.978789     4315.622723     4519.094331
# Colombia             Americas     2144.115096     2323.805581     2492.351109
# Costa Rica           Americas     2627.009471     2990.010802     3460.937025
# Cuba                 Americas     5586.538780     6092.174359     5180.755910
# Dominican Republic   Americas     1397.717137     1544.402995     1662.137359
# Ecuador              Americas     3522.110717     3780.546651     4086.114078
# El Salvador          Americas     3048.302900     3421.523218     3776.803627
# ...

# %%
df_americas.head(10)
# Out:
#                    continent  gdpPercap_1952  gdpPercap_1957  gdpPercap_1962  \
# country
# Argentina           Americas     5911.315053     6856.856212     7133.166023
# Bolivia             Americas     2677.326347     2127.686326     2180.972546
# Brazil              Americas     2108.944355     2487.365989     3336.585802
# Canada              Americas    11367.161120    12489.950060    13462.485550
# Chile               Americas     3939.978789     4315.622723     4519.094331
# Colombia            Americas     2144.115096     2323.805581     2492.351109
# Costa Rica          Americas     2627.009471     2990.010802     3460.937025
# Cuba                Americas     5586.538780     6092.174359     5180.755910
# Dominican Republic  Americas     1397.717137     1544.402995     1662.137359
# Ecuador             Americas     3522.110717     3780.546651     4086.114078
#
#                     gdpPercap_1967  gdpPercap_1972  gdpPercap_1977  \
# country
# ...

# %%
df_americas.tail()
# Out:
#                     continent  gdpPercap_1952  gdpPercap_1957  gdpPercap_1962  \
# country
# Puerto Rico          Americas     3081.959785     3907.156189     5108.344630
# Trinidad and Tobago  Americas     3023.271928     4100.393400     4997.523971
# United States        Americas    13990.482080    14847.127120    16173.145860
# Uruguay              Americas     5716.766744     6150.772969     5603.357717
# Venezuela            Americas     7689.799761     9802.466526     8422.974165
#
#                      gdpPercap_1967  gdpPercap_1972  gdpPercap_1977  \
# country
# Puerto Rico             6929.277714     9123.041742     9770.524921
# Trinidad and Tobago     5621.368472     6619.551419     7899.554209
# United States          19530.365570    21806.035940    24072.632130
# Uruguay                 5444.619620     5703.408898     6504.339663
# Venezuela               9541.474188    10505.259660    13143.950950
#
# ...

# %%
a_tail10=df_americas.tail(10)
a_tail10.to_csv("data/americas_tail10.csv")

# %%
df_europe = pd.read_csv("data/gapminder_gdp_europe.csv", index_col = 'country')
df_europe
# Out:
#                         gdpPercap_1952  gdpPercap_1957  gdpPercap_1962  \
# country
# Albania                    1601.056136     1942.284244     2312.888958
# Austria                    6137.076492     8842.598030    10750.721110
# Belgium                    8343.105127     9714.960623    10991.206760
# Bosnia and Herzegovina      973.533195     1353.989176     1709.683679
# Bulgaria                   2444.286648     3008.670727     4254.337839
# Croatia                    3119.236520     4338.231617     5477.890018
# Czech Republic             6876.140250     8256.343918    10136.867130
# Denmark                    9692.385245    11099.659350    13583.313510
# Finland                    6424.519071     7545.415386     9371.842561
# France                     7029.809327     8662.834898    10560.485530
# Germany                    7144.114393    10187.826650    12902.462910
# Greece                     3530.690067     4916.299889     6017.190733
# ...

# %%
df_europe.iloc[1,0]
df_europe.iloc[6,4]
# Out:
# 13108.4536

# %%
df_europe.loc["Albania", "gdpPercap_1972"]
# Out:
# 3313.422188

# %%
df_europe.loc["Albania", :]
# Out:
# gdpPercap_1952    1601.056136
# gdpPercap_1957    1942.284244
# gdpPercap_1962    2312.888958
# gdpPercap_1967    2760.196931
# gdpPercap_1972    3313.422188
# gdpPercap_1977    3533.003910
# gdpPercap_1982    3630.880722
# gdpPercap_1987    3738.932735
# gdpPercap_1992    2497.437901
# gdpPercap_1997    3193.054604
# gdpPercap_2002    4604.211737
# gdpPercap_2007    5937.029526
# Name: Albania, dtype: float64

# %%
df_europe.loc["Albania", "gdpPercap_1952":"gdpPercap_1972"]
# Out:
# gdpPercap_1952    1601.056136
# gdpPercap_1957    1942.284244
# gdpPercap_1962    2312.888958
# gdpPercap_1967    2760.196931
# gdpPercap_1972    3313.422188
# Name: Albania, dtype: float64

# %%
 #iloc uses the position in the matrix of the dataframe - does not include the nth value
df_europe.iloc[0:4][1:2]
# Out:
#          gdpPercap_1952  gdpPercap_1957  gdpPercap_1962  gdpPercap_1967  \
# country
# Austria     6137.076492      8842.59803     10750.72111      12834.6024
#
#          gdpPercap_1972  gdpPercap_1977  gdpPercap_1982  gdpPercap_1987  \
# country
# Austria      16661.6256      19749.4223     21597.08362     23687.82607
#
#          gdpPercap_1992  gdpPercap_1997  gdpPercap_2002  gdpPercap_2007
# country
# Austria     27042.01868     29095.92066     32417.60769      36126.4927

# %%
df_europe.iloc[1:3]
# Out:
#          gdpPercap_1952  gdpPercap_1957  gdpPercap_1962  gdpPercap_1967  \
# country
# Austria     6137.076492     8842.598030     10750.72111     12834.60240
# Belgium     8343.105127     9714.960623     10991.20676     13149.04119
#
#          gdpPercap_1972  gdpPercap_1977  gdpPercap_1982  gdpPercap_1987  \
# country
# Austria     16661.62560     19749.42230     21597.08362     23687.82607
# Belgium     16672.14356     19117.97448     20979.84589     22525.56308
#
#          gdpPercap_1992  gdpPercap_1997  gdpPercap_2002  gdpPercap_2007
# country
# Austria     27042.01868     29095.92066     32417.60769     36126.49270
# Belgium     25575.57069     27561.19663     30485.88375     33692.60508

# %%
df_europe.iloc[0:4][1:2]

# %%
df_europe.iloc[0:][1:2]
# Out:
#          gdpPercap_1952  gdpPercap_1957  gdpPercap_1962  gdpPercap_1967  \
# country
# Austria     6137.076492      8842.59803     10750.72111      12834.6024
#
#          gdpPercap_1972  gdpPercap_1977  gdpPercap_1982  gdpPercap_1987  \
# country
# Austria      16661.6256      19749.4223     21597.08362     23687.82607
#
#          gdpPercap_1992  gdpPercap_1997  gdpPercap_2002  gdpPercap_2007
# country
# Austria     27042.01868     29095.92066     32417.60769      36126.4927

# %%
df_europe.loc["Albania", :][1:3]
# Out:
# gdpPercap_1957    1942.284244
# gdpPercap_1962    2312.888958
# Name: Albania, dtype: float64

# %%
subset = df_europe.loc["Italy": "Poland", "gdpPercap_1952":"gdpPercap_1972"]

# %%
subset
# Out:
#              gdpPercap_1952  gdpPercap_1957  gdpPercap_1962  gdpPercap_1967  \
# country
# Italy           4931.404155     6248.656232     8243.582340    10022.401310
# Montenegro      2647.585601     3682.259903     4649.593785     5907.850937
# Netherlands     8941.571858    11276.193440    12790.849560    15363.251360
# Norway         10095.421720    11653.973040    13450.401510    16361.876470
# Poland          4029.329699     4734.253019     5338.752143     6557.152776
#
#              gdpPercap_1972
# country
# Italy          12269.273780
# Montenegro      7778.414017
# Netherlands    18794.745670
# Norway         18965.055510
# Poland          8006.506993

# %%
mask = subset > 10000             # Boolean masking
mask
# Out:
#              gdpPercap_1952  gdpPercap_1957  gdpPercap_1962  gdpPercap_1967  \
# country
# Italy                 False           False           False            True
# Montenegro            False           False           False           False
# Netherlands           False            True            True            True
# Norway                 True            True            True            True
# Poland                False           False           False           False
#
#              gdpPercap_1972
# country
# Italy                  True
# Montenegro            False
# Netherlands            True
# Norway                 True
# Poland                False

# %%
subset[mask]    # can do this without saving to mask subset[subset > 10000]
# Out:
#              gdpPercap_1952  gdpPercap_1957  gdpPercap_1962  gdpPercap_1967  \
# country
# Italy                   NaN             NaN             NaN     10022.40131
# Montenegro              NaN             NaN             NaN             NaN
# Netherlands             NaN     11276.19344     12790.84956     15363.25136
# Norway          10095.42172     11653.97304     13450.40151     16361.87647
# Poland                  NaN             NaN             NaN             NaN
#
#              gdpPercap_1972
# country
# Italy           12269.27378
# Montenegro              NaN
# Netherlands     18794.74567
# Norway          18965.05551
# Poland                  NaN

# %%
subset[subset > 10000]
# Out:
#              gdpPercap_1952  gdpPercap_1957  gdpPercap_1962  gdpPercap_1967  \
# country
# Italy                   NaN             NaN             NaN     10022.40131
# Montenegro              NaN             NaN             NaN             NaN
# Netherlands             NaN     11276.19344     12790.84956     15363.25136
# Norway          10095.42172     11653.97304     13450.40151     16361.87647
# Poland                  NaN             NaN             NaN             NaN
#
#              gdpPercap_1972
# country
# Italy           12269.27378
# Montenegro              NaN
# Netherlands     18794.74567
# Norway          18965.05551
# Poland                  NaN

# %%
subset[mask].describe()
# Out:
#        gdpPercap_1952  gdpPercap_1957  gdpPercap_1962  gdpPercap_1967  \
# count         1.00000        2.000000        2.000000        3.000000
# mean      10095.42172    11465.083240    13120.625535    13915.843047
# std               NaN      267.130517      466.373656     3408.589070
# min       10095.42172    11276.193440    12790.849560    10022.401310
# 25%       10095.42172    11370.638340    12955.737548    12692.826335
# 50%       10095.42172    11465.083240    13120.625535    15363.251360
# 75%       10095.42172    11559.528140    13285.513522    15862.563915
# max       10095.42172    11653.973040    13450.401510    16361.876470
#
#        gdpPercap_1972
# count        3.000000
# mean     16676.358320
# std       3817.597015
# min      12269.273780
# 25%      15532.009725
# 50%      18794.745670
# 75%      18879.900590
# max      18965.055510

# %%
df_europe.mean()
# Out:
# gdpPercap_1952     5661.057435
# gdpPercap_1957     6963.012816
# gdpPercap_1962     8365.486814
# gdpPercap_1967    10143.823757
# gdpPercap_1972    12479.575246
# gdpPercap_1977    14283.979110
# gdpPercap_1982    15617.896551
# gdpPercap_1987    17214.310727
# gdpPercap_1992    17061.568084
# gdpPercap_1997    19076.781802
# gdpPercap_2002    21711.732422
# gdpPercap_2007    25054.481636
# dtype: float64

# %%
#Boolean mask to extract countires with higher gdp (> mean)
mask_higher = df_europe > df_europe.mean()
mask_higher
# Out:
#                         gdpPercap_1952  gdpPercap_1957  gdpPercap_1962  \
# country
# Albania                          False           False           False
# Austria                           True            True            True
# Belgium                           True            True            True
# Bosnia and Herzegovina           False           False           False
# Bulgaria                         False           False           False
# Croatia                          False           False           False
# Czech Republic                    True            True            True
# Denmark                           True            True            True
# Finland                           True            True            True
# France                            True            True            True
# Germany                           True            True            True
# Greece                           False           False           False
# ...

# %%
mask_higher.head()
# Out:
#                         gdpPercap_1952  gdpPercap_1957  gdpPercap_1962  \
# country
# Albania                          False           False           False
# Austria                           True            True            True
# Belgium                           True            True            True
# Bosnia and Herzegovina           False           False           False
# Bulgaria                         False           False           False
#
#                         gdpPercap_1967  gdpPercap_1972  gdpPercap_1977  \
# country
# Albania                          False           False           False
# Austria                           True            True            True
# Belgium                           True            True            True
# Bosnia and Herzegovina           False           False           False
# Bulgaria                         False           False           False
#
#                         gdpPercap_1982  gdpPercap_1987  gdpPercap_1992  \
# country
# ...

# %%
mask_higher.aggregate("sum", axis=1).head()
# Out:
# country
# Albania                    0
# Austria                   12
# Belgium                   12
# Bosnia and Herzegovina     0
# Bulgaria                   0
# dtype: int64

# %%
mask_higher.aggregate("sum", axis=1) / len(df_europe.columns)
# Out:
# country
# Albania                   0.000000
# Austria                   1.000000
# Belgium                   1.000000
# Bosnia and Herzegovina    0.000000
# Bulgaria                  0.000000
# Croatia                   0.000000
# Czech Republic            0.500000
# Denmark                   1.000000
# Finland                   1.000000
# France                    1.000000
# Germany                   1.000000
# Greece                    0.333333
# Hungary                   0.000000
# Iceland                   1.000000
# Ireland                   0.333333
# Italy                     0.500000
# Montenegro                0.000000
# Netherlands               1.000000
# Norway                    1.000000
# Poland                    0.000000
# Portugal                  0.000000
# Romania                   0.000000
# Serbia                    0.000000
# Slovak Republic           0.000000
# Slovenia                  0.333333
# Spain                     0.333333
# ...

# %%
wealth_score = mask_higher.aggregate("sum", axis=1) / len(df_europe.columns)

# %%
df_europe.groupby(wealth_score)
